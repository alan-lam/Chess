# %%
# TODO: if king is in check, go through valid moves of king and see if each move is in opponent's valid moves; remove if so
        # if there is at least one valid move, remove board's check flag
        # if there are no moves, checkmate

# %%
import pandas as pd

# %%
class Piece:
    
    def __init__(self, piecetype, file, rank, color):
        self.piecetype = piecetype
        self.file = file
        self.rank = rank
        self.color = color
        self.valid_moves = set()
    
class Rook(Piece):
    
    def __init__(self, file, rank, color):
        super().__init__('r', file, rank, color)
        
    def __str__(self):
        if self.color == 'black':
            return 'r'
        return 'R'

class Knight(Piece):
    
    def __init__(self, file, rank, color):
        super().__init__('n', file, rank, color)
        
    def __str__(self):
        if self.color == 'black':
            return 'n'
        return 'N'
    
class Bishop(Piece):
    
    def __init__(self, file, rank, color):
        super().__init__('b', file, rank, color)
        
    def __str__(self):
        if self.color == 'black':
            return 'b'
        return 'B'
    
class King(Piece):
    
    def __init__(self, file, rank, color):
        super().__init__('k', file, rank, color)
        
    def __str__(self):
        if self.color == 'black':
            return 'k'
        return 'K'

class Queen(Piece):
    
    def __init__(self, file, rank, color):
        super().__init__('q', file, rank, color)
        
    def __str__(self):
        if self.color == 'black':
            return 'q'
        return 'Q'

class Pawn(Piece):
    
    def __init__(self, file, rank, color):
        super().__init__('p', file, rank, color)
        
    def __str__(self):
        if self.color == 'black':
            return 'p'
        return 'P'

class Board:
    
    board = None
    turn = 'white'
    check = False # True if any king is in check
    BlackRook1 = Rook('a','8','black')
    BlackKnight1 = Knight('b','8','black')
    BlackBishop1 = Bishop('c','8','black')
    BlackQueen = Queen('d','8','black')
    BlackKing = King('e','8','black')
    BlackBishop2 = Bishop('f','8','black')
    BlackKnight2 = Knight('g','8','black')
    BlackRook2 = Rook('h','8','black')
    BlackPawn1 = Pawn('a','7','black')
    BlackPawn2 = Pawn('b','7','black')
    BlackPawn3 = Pawn('c','7','black')
    BlackPawn4 = Pawn('d','7','black')
    BlackPawn5 = Pawn('e','7','black')
    BlackPawn6 = Pawn('f','7','black')
    BlackPawn7 = Pawn('g','7','black')
    BlackPawn8 = Pawn('h','7','black')
    WhiteRook1 = Rook('a','1','white')
    WhiteKnight1 = Knight('b','1','white')
    WhiteBishop1 = Bishop('c','1','white')
    WhiteQueen = Queen('d','1','white')
    WhiteKing = King('e','1','white')
    WhiteBishop2 = Bishop('f','1','white')
    WhiteKnight2 = Knight('g','1','white')
    WhiteRook2 = Rook('h','1','white')
    WhitePawn1 = Pawn('a','2','white')
    WhitePawn2 = Pawn('b','2','white')
    WhitePawn3 = Pawn('c','2','white')
    WhitePawn4 = Pawn('d','2','white')
    WhitePawn5 = Pawn('e','2','white')
    WhitePawn6 = Pawn('f','2','white')
    WhitePawn7 = Pawn('g','2','white')
    WhitePawn8 = Pawn('h','2','white')
    
    def __init__(self):
        indices = '8,7,6,5,4,3,2,1'.split(',')
        columns = 'a,b,c,d,e,f,g,h'.split(',')
        self.board = pd.DataFrame(data='', index=indices, columns=columns)
        # put pieces in starting positions
        self.board.loc['8'] = [self.BlackRook1, self.BlackKnight1, self.BlackBishop1, self.BlackQueen,
                               self.BlackKing, self.BlackBishop2, self.BlackKnight2, self.BlackRook2]
        self.board.loc['7'] = [self.BlackPawn1, self.BlackPawn2, self.BlackPawn3, self.BlackPawn4,
                               self.BlackPawn5, self.BlackPawn6, self.BlackPawn7, self.BlackPawn8]
        self.board.loc['1'] = [self.WhiteRook1, self.WhiteKnight1, self.WhiteBishop1, self.WhiteQueen,
                               self.WhiteKing, self.WhiteBishop2, self.WhiteKnight2, self.WhiteRook2]
        self.board.loc['2'] = [self.WhitePawn1, self.WhitePawn2, self.WhitePawn3, self.WhitePawn4,
                               self.WhitePawn5, self.WhitePawn6, self.WhitePawn7, self.WhitePawn8]
        
    def print_board(self):
        display(self.board)

# %%
def get_rook_moves(piece, x, y, x_dir):
    # check if can move up
    while int(y) < 8:
        y = str(int(y)+1)
        # can move to empty space
        if type(board.board[x][y]) == str:
            piece.valid_moves.add(x + y)
        # can capture enemy piece
        elif board.board[x][y].color != piece.color:
            piece.valid_moves.add(x + y)
            # can check king
            if board.board[x][y].piecetype == 'k':
                board.check = True
            break
        # ally piece
        else:
            break
                    
    y = piece.rank

    # check if can move down
    while int(y) > 1:
        y = str(int(y)-1)
        # can move to empty space
        if type(board.board[x][y]) == str:
            piece.valid_moves.add(x + y)
        # can capture enemy piece
        elif board.board[x][y].color != piece.color:
            piece.valid_moves.add(x + y)
            # can check king
            if board.board[x][y].piecetype == 'k':
                board.check = True
            break
        # ally piece
        else:
            break
            
    y = piece.rank
        
    # check if can move left
    while x_dir.index(x) > 0:
        x = chr(ord(x)-1)
        # can move to empty space
        if type(board.board[x][y]) == str:
            piece.valid_moves.add(x + y)
        # can capture enemy piece
        elif board.board[x][y].color != piece.color:
            piece.valid_moves.add(x + y)
            # can check king
            if board.board[x][y].piecetype == 'k':
                board.check = True
            break
        # ally piece
        else:
            break

    x = piece.file

    # check if can move right
    while x_dir.index(x) < 7:
        x = chr(ord(x)+1)
        # can move to empty space
        if type(board.board[x][y]) == str:
            piece.valid_moves.add(x + y)
        # can capture enemy piece
        elif board.board[x][y].color != piece.color:
            piece.valid_moves.add(x + y)
            # can check king
            if board.board[x][y].piecetype == 'k':
                board.check = True
            break
        # ally piece
        else:
            break

# %%
def get_knight_moves(piece, x, y, x_dir):
    # check if can move left
    if chr(ord(x)-2) in x_dir:
        if int(y)+1 < 9:
            cell = board.board[chr(ord(x)-2)][str(int(y)+1)]
            # can move to empty space
            if type(cell) == str:
                piece.valid_moves.add(chr(ord(x)-2) + str(int(y)+1))
            # can capture enemy piece
            elif cell.color != piece.color:
                piece.valid_moves.add(chr(ord(x)-2) + str(int(y)+1))
                # can check king
                if cell.piecetype == 'k':
                    board.check = True
        if int(y)-1 > 0:
            cell = board.board[chr(ord(x)-2)][str(int(y)-1)]
            # can move to empty space
            if type(cell) == str:
                piece.valid_moves.add(chr(ord(x)-2) + str(int(y)-1))
            # can capture enemy piece
            elif cell.color != piece.color:
                piece.valid_moves.add(chr(ord(x)-2) + str(int(y)-1))
                # can check king
                if cell.piecetype == 'k':
                    board.check = True
                    
    # check if can move right
    if chr(ord(x)+2) in x_dir:
        if int(y)+1 < 9:
            cell = board.board[chr(ord(x)+2)][str(int(y)+1)]
            # can move to empty space
            if type(cell) == str:
                piece.valid_moves.add(chr(ord(x)+2) + str(int(y)+1))
            # can capture enemy piece
            elif cell.color != piece.color:
                piece.valid_moves.add(chr(ord(x)+2) + str(int(y)+1))
                # can check king
                if cell.piecetype == 'k':
                    board.check = True
        if int(y)-1 > 0:
            cell = board.board[chr(ord(x)+2)][str(int(y)-1)]
            # can move to empty space
            if type(cell) == str:
                piece.valid_moves.add(chr(ord(x)+2) + str(int(y)-1))
            # can capture enemy piece
            elif cell.color != piece.color:
                piece.valid_moves.add(chr(ord(x)+2) + str(int(y)-1))
                # can check king
                if cell.piecetype == 'k':
                    board.check = True
    
    # check if can move up
    if int(y)+2 < 9:
        if chr(ord(x)-1) in x_dir:
            cell = board.board[chr(ord(x)-1)][str(int(y)+2)]
            # can move to empty space
            if type(cell) == str:
                piece.valid_moves.add(chr(ord(x)-1) + str(int(y)+2))
            # can capture enemy piece
            elif cell.color != piece.color:
                piece.valid_moves.add(chr(ord(x)-1) + str(int(y)+2))
                # can check king
                if cell.piecetype == 'k':
                    board.check = True
        if chr(ord(x)+1) in x_dir:
            cell = board.board[chr(ord(x)+1)][str(int(y)+2)]
            # can move to empty space
            if type(cell) == str:
                piece.valid_moves.add(chr(ord(x)+1) + str(int(y)+2))
            # can capture enemy piece
            elif cell.color != piece.color:
                piece.valid_moves.add(chr(ord(x)+1) + str(int(y)+2))
                # can check king
                if cell.piecetype == 'k':
                    board.check = True
                    
    # check if can move down
    if int(y)-2 > 0:
        if chr(ord(x)-1) in x_dir:
            cell = board.board[chr(ord(x)-1)][str(int(y)-2)]
            # can move to empty space or capture enemy piece
            if type(cell) == str:
                piece.valid_moves.add(chr(ord(x)-1) + str(int(y)-2))
            # can capture enemy piece
            elif cell.color != piece.color:
                piece.valid_moves.add(chr(ord(x)-1) + str(int(y)-2))
                # can check king
                if cell.piecetype == 'k':
                    board.check = True
        if chr(ord(x)+1) in x_dir:
            cell = board.board[chr(ord(x)+1)][str(int(y)-2)]
            # can move to empty space or capture enemy piece
            if type(cell) == str:
                piece.valid_moves.add(chr(ord(x)+1) + str(int(y)-2))
            # can capture enemy piece
            elif cell.color != piece.color:
                piece.valid_moves.add(chr(ord(x)+1) + str(int(y)-2))
                # can check king
                if cell.piecetype == 'k':
                    board.check = True

# %%
def get_bishop_moves(piece, x, y, x_dir):
    # check if can move up-right
    while x_dir.index(x) < 7 and int(y) < 8:
        x = chr(ord(x)+1)
        y = str(int(y)+1)
        # can move to empty space
        if type(board.board[x][y]) == str:
            piece.valid_moves.add(x + y)
        # can capture enemy piece
        elif board.board[x][y].color != piece.color:
            piece.valid_moves.add(x + y)
            # can check king
            if board.board[x][y].piecetype == 'k':
                board.check = True
            break
        # ally piece
        else:
            break
            
    x = piece.file
    y = piece.rank
    
    # check if can move up-left
    while x_dir.index(x) > 0 and int(y) < 8:
        x = chr(ord(x)-1)
        y = str(int(y)+1)
        # can move to empty space
        if type(board.board[x][y]) == str:
            piece.valid_moves.add(x + y)
        # can capture enemy piece
        elif board.board[x][y].color != piece.color:
            piece.valid_moves.add(x + y)
            # can check king
            if board.board[x][y].piecetype == 'k':
                board.check = True
            break
        # ally piece
        else:
            break
            
    x = piece.file
    y = piece.rank
    
    # check if can move down-right
    while x_dir.index(x) < 7 and int(y) > 1:
        x = chr(ord(x)+1)
        y = str(int(y)-1)
        # can move to empty space
        if type(board.board[x][y]) == str:
            piece.valid_moves.add(x + y)
        # can capture enemy piece
        elif board.board[x][y].color != piece.color:
            piece.valid_moves.add(x + y)
            # can check king
            if board.board[x][y].piecetype == 'k':
                board.check = True
            break
        # ally piece
        else:
            break
    
    x = piece.file
    y = piece.rank
    
    # check if can move down-left
    while x_dir.index(x) > 0 and int(y) > 1:
        x = chr(ord(x)-1)
        y = str(int(y)-1)
        # can move to empty space
        if type(board.board[x][y]) == str:
            piece.valid_moves.add(x + y)
        # can capture enemy piece
        elif board.board[x][y].color != piece.color:
            piece.valid_moves.add(x + y)
            # can check king
            if board.board[x][y].piecetype == 'k':
                board.check = True
            break
        # ally piece
        else:
            break

# %%
def get_king_moves(piece, x, y, x_dir):
    can_move_up = False
    can_move_down = False
    can_move_left = False
    can_move_right = False

    # check if can move up
    if int(y)+1 < 9:
        can_move_up = True
        cell = board.board[x][str(int(y)+1)]
        # can move to empty space or capture enemy piece
        if type(cell) == str or cell.color != piece.color:
            piece.valid_moves.add(x + str(int(y)+1))
            
    # check if can move down
    if int(y)-1 > 0:
        can_move_down = True
        cell = board.board[x][str(int(y)-1)]
        # can move to empty space or capture enemy piece
        if type(cell) == str or cell.color != piece.color:
            piece.valid_moves.add(x + str(int(y)-1))
        
    # check if can move left
    if chr(ord(x)-1) in x_dir:
        can_move_left = True
        cell = board.board[chr(ord(x)-1)][y]
        # can move to empty space or capture enemy piece
        if type(cell) == str or cell.color != piece.color:
            piece.valid_moves.add(chr(ord(x)-1) + y)
            
    # check if can move right
    if chr(ord(x)+1) in x_dir:
        can_move_right = True
        cell = board.board[chr(ord(x)+1)][y]
        # can move to empty space or capture enemy piece
        if type(cell) == str or cell.color != piece.color:
            piece.valid_moves.add(chr(ord(x)+1) + y)
        
    # check if can move up-left and up-right
    if can_move_up:
        if can_move_left:
            cell = board.board[chr(ord(x)-1)][str(int(y)+1)]
            # can move to empty space or capture enemy piece
            if type(cell) == str or cell.color != piece.color:
                piece.valid_moves.add(chr(ord(x)-1) + str(int(y)+1))
        if can_move_right:
            cell = board.board[chr(ord(x)+1)][str(int(y)+1)]
            # can move to empty space or capture enemy piece
            if type(cell) == str or cell.color != piece.color:
                piece.valid_moves.add(chr(ord(x)+1) + str(int(y)+1))
    
    # check if can move down-left and down-right
    if can_move_down:
        if can_move_left:
            cell = board.board[chr(ord(x)-1)][str(int(y)-1)]
            # can move to empty space or capture enemy piece
            if type(cell) == str or cell.color != piece.color:
                piece.valid_moves.add(chr(ord(x)-1) + str(int(y)-1))
        if can_move_right:
            cell = board.board[chr(ord(x)+1)][str(int(y)-1)]
            # can move to empty space or capture enemy piece
            if type(cell) == str or cell.color != piece.color:
                piece.valid_moves.add(chr(ord(x)+1) + str(int(y)-1))

# %%
def get_pawn_moves(piece, x, y, x_dir):
    if piece.color == 'black':
        # check if can move forward one space
        if type(board.board[x][str(int(y)-1)]) == str:
            piece.valid_moves.add(x + str(int(y)-1))
        # check if can move forward two spaces
        if y == '7':
            if type(board.board[x][str(int(y)-2)]) == str:
                piece.valid_moves.add(x + str(int(y)-2))
        # can capture enemy piece
        if chr(ord(x)-1) in x_dir:
            cell = board.board[chr(ord(x)-1)][str(int(y)-1)]
            if type(cell) != str and cell.color != piece.color:
                piece.valid_moves.add(chr(ord(x)-1) + str(int(y)-1))
                # can check king
                if cell.piece == 'k':
                    board.check = True
        if chr(ord(x)+1) in x_dir:
            cell = board.board[chr(ord(x)+1)][str(int(y)-1)]
            if type(cell) != str and cell.color != piece.color:
                piece.valid_moves.add(chr(ord(x)+1) + str(int(y)-1))
                # can check king
                if cell.piece == 'k':
                    board.check = True
    else:
        # check if can move forward one space
        if type(board.board[x][str(int(y)+1)]) == str:
            piece.valid_moves.add(x + str(int(y)+1))
        # check if can move forward two spaces
        if y == '2':
            if type(board.board[x][str(int(y)+2)]) == str:
                piece.valid_moves.add(x + str(int(y)+2))
        # can capture enemy piece
        if chr(ord(x)-1) in x_dir:
            cell = board.board[chr(ord(x)-1)][str(int(y)+1)]
            if type(cell) != str and cell.color != piece.color:
                piece.valid_moves.add(chr(ord(x)-1) + str(int(y)+1))
                # can check king
                if cell.piece == 'k':
                    board.check = True
        if chr(ord(x)+1) in x_dir:
            cell = board.board[chr(ord(x)+1)][str(int(y)+1)]
            if type(cell) != str and cell.color != piece.color:
                piece.valid_moves.add(chr(ord(x)+1) + str(int(y)+1))
                # can check king
                if cell.piece == 'k':
                    board.check = True

# %%
def get_valid_moves(piece):
    if type(piece) != str:
        x_dir = 'a,b,c,d,e,f,g,h'.split(',') # used to check if left and right are valid moves
        x = piece.file
        y = piece.rank
        
        if type(piece) == Rook:
            get_rook_moves(piece,x,y,x_dir)
                    
        if type(piece) == Knight:
            get_knight_moves(piece,x,y,x_dir)
            
        if type(piece) == Bishop:
            get_bishop_moves(piece,x,y,x_dir)
            
        if type(piece) == Queen:
            get_rook_moves(piece,x,y,x_dir)
            get_bishop_moves(piece,x,y,x_dir)
            pass
            
        if type(piece) == King:
            get_king_moves(piece,x,y,x_dir)
            
        if type(piece) == Pawn:
            get_pawn_moves(piece,x,y,x_dir)

# %%
def print_valid_moves(piece):
    if type(piece) != str:
        print(str(piece) + ': ' + str(piece.valid_moves))

# %%
board = Board()
board.board.applymap(get_valid_moves);
# board.board.applymap(print_valid_moves)

# %%
# move must follow format:
# piecetype, file it's at, rank it's at, file to move to, rank to move to

bad_input = True
move = ''
while bad_input:
    move = input('Enter move: ')
    # check if input follows format
    if (len(move) == 5 and move[1] in 'abcdefgh' and move[2] in '12345678'
        and move[3] in 'abcdefgh' and move[4] in '12345678'):
        if board.turn == 'white':
            if move[0] in 'RNBQKP':
                bad_input = False
        else:
            if move[0] in 'rnbqkp':
                bad_input = False
    
    # check if piece exists and if move is valid
    if bad_input == False:
        piecetype = move[0]
        position_file = move[1]
        position_rank = move[2]
        move_to = move[3:]

        piece = board.board[position_file][position_rank]
        if piecetype != piece.__str__() or move_to not in piece.valid_moves:
            bad_input = True
